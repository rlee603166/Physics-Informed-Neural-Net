# %%
# !pip install scipy
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import scipy.io as sio
import numpy as np

# %%
# Load .mat file
mat_data = sio.loadmat('romberg.mat')

# Explore structure
print(mat_data.keys())  # Shows all variables
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'DataFileName', 'Total_Distance_COH', 'Total_Distance_COM', 'Total_Distance_COP', 'COP_Top_Right', 'COP_Top_Left', 'COP_Bottom_Right', 'COP_Bottom_Left', 'COM_Top_Right', 'COM_Top_Left', 'COM_Bottom_Right', 'COM_Bottom_Left', 'COH_Top_Right', 'COH_Top_Left', 'COH_Bottom_Right', 'COH_Bottom_Left', 'Ellipse_z_COP', 'Ellipse_z_COM', 'Ellipse_z_COH', 'Sway_dist_COP_Sag', 'Sway_dist_COP_Cor', 'Sway_dist_COM_Sag', 'Sway_dist_COM_Cor', 'Sway_dist_COH_Sag', 'Sway_dist_COH_Cor', 'COH_Anterior_Tilt', 'COH_Left_Tilt', 'COH_Posterior_Tilt', 'COH_Right_Tilt', 'LAnkle_Flex_Max_Anter_COH', 'RAnkle_Flex_Max_Anter_COH', 'LKnee_Flex_Max_Anter_COH', 'RKnee_Flex_Max_Anter_COH', 'LHip_Flex_Max_Anter_COH', 'RHip_Flex_Max_Anter_COH', 'LAnkle_Flex_Max_Post_COH', 'RAnkle_Flex_Max_Post_COH', 'LKnee_Flex_Max_Post_COH', 'RKnee_Flex_Max_Post_COH', 'LHip_Flex_Max_Post_COH', 'RHip_Flex_Max_Post_COH', 'COH_AvgSwaySag', 'COH_AvgSwayCor', 'COH_AvgTotDist', 'COM_A
# ...

# %%
print("TrajX shape:", mat_data['TrajX'].shape)
print("TrajY shape:", mat_data['TrajY'].shape) 
print("DeviceOutX shape:", mat_data['DeviceOutX'].shape)

# Look at first few values
print("TrajX sample:", mat_data['TrajX'][:10])
# Out:
# TrajX shape: (1, 1)
# TrajY shape: (1, 1)
# DeviceOutX shape: (1, 1)
# ...

# %%
trajx_trials = mat_data['TrajX'][0][0]  # Get the actual trial data
trajy_trials = mat_data['TrajY'][0][0]

print(f"Number of trials: {len(trajx_trials)}")
print(f"Points per trial: {trajx_trials[0].shape}")
print(f"First trial X data: {trajx_trials[0][0][:10]}")  # First 10 points
# Out:
# Number of trials: 3
# Points per trial: (1, 1)
# ...

# %%
import json
with open('romberg.json', 'r') as f:
    data = json.load(f)
print(len(data))
# Out:
# 3

# %%
print(len(data["romberg_files"]))
# Out:
# 281
